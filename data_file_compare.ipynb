# %%
import pandas as pd
import numpy as np

# %%
df1 =pd.read_csv('Audible_Catlog.csv')
df2 = pd.read_csv('Audible_catlog_Advanced_Features.csv')

# %%
df1
# Out:
#                                               Book Name           Author  \
# 0     Think Like a Monk: The Secret of How to Harnes...       Jay Shetty
# 1     Ikigai: The Japanese Secret to a Long and Happ...    Héctor García
# 2     The Subtle Art of Not Giving a F*ck: A Counter...      Mark Manson
# 3     Atomic Habits: An Easy and Proven Way to Build...      James Clear
# 4     Life's Amazing Secrets: How to Find Balance an...   Gaur Gopal Das
# ...                                                 ...              ...
# 6363                                 The Hot Flash Club     Nancy Thayer
# 6364                         The Prophet & The Wanderer    Khalil Gibran
# 6365  Make Today Count: The Secret of Your Success I...  John C. Maxwell
# 6366  25 Hours a Day: Going One More to Get What You...        Nick Bare
# 6367                             वॉयर - एक कामुक लघुकथा    सेसिलि रोसडैल
#
#       Rating  Number of Reviews    Price
# 0        4.9              313.0  10080.0
# ...

# %%
df2
# Out:
#                                               Book Name                Author  \
# 0     Think Like a Monk: The Secret of How to Harnes...            Jay Shetty
# 1     Ikigai: The Japanese Secret to a Long and Happ...         Héctor García
# 2     The Subtle Art of Not Giving a F*ck: A Counter...           Mark Manson
# 3     Atomic Habits: An Easy and Proven Way to Build...           James Clear
# 4     Life's Amazing Secrets: How to Find Balance an...        Gaur Gopal Das
# ...                                                 ...                   ...
# 4459  Factfulness: Wie wir lernen, die Welt so zu se...          Hans Rosling
# 4460       Late-Talking Children: A Symptom or a Stage?   Stephen M. Camarata
# 4461  The Marketing of Evil: How Radicals, Elitists ...        David Kupelian
# 4462      Things I Wish I'd Known Before We Got Married          Gary Chapman
# 4463  The Disease Delusion: Conquering the Causes of...  Dr. Jeffrey S. Bland
#
# ...

# %%
df = pd.merge(df1, df2, on="Book Name", how = 'left')
df
# Out:
#                                               Book Name         Author_x  \
# 0     Think Like a Monk: The Secret of How to Harnes...       Jay Shetty
# 1     Ikigai: The Japanese Secret to a Long and Happ...    Héctor García
# 2     The Subtle Art of Not Giving a F*ck: A Counter...      Mark Manson
# 3     Atomic Habits: An Easy and Proven Way to Build...      James Clear
# 4     Life's Amazing Secrets: How to Find Balance an...   Gaur Gopal Das
# ...                                                 ...              ...
# 6826  Make Today Count: The Secret of Your Success I...  John C. Maxwell
# 6827  Make Today Count: The Secret of Your Success I...  John C. Maxwell
# 6828  25 Hours a Day: Going One More to Get What You...        Nick Bare
# 6829                             वॉयर - एक कामुक लघुकथा    सेसिलि रोसडैल
# 6830                             वॉयर - एक कामुक लघुकथा    सेसिलि रोसडैल
#
#       Rating_x  Number of Reviews_x  Price_x         Author_y  Rating_y  \
# ...

# %%
df = pd.merge(df1, df2, on='Book Name', how='inner')
df
# Out:
#                                               Book Name         Author_x  \
# 0     Think Like a Monk: The Secret of How to Harnes...       Jay Shetty
# 1     Ikigai: The Japanese Secret to a Long and Happ...    Héctor García
# 2     The Subtle Art of Not Giving a F*ck: A Counter...      Mark Manson
# 3     Atomic Habits: An Easy and Proven Way to Build...      James Clear
# 4     Life's Amazing Secrets: How to Find Balance an...   Gaur Gopal Das
# ...                                                 ...              ...
# 4265                         The Prophet & The Wanderer    Khalil Gibran
# 4266  Make Today Count: The Secret of Your Success I...  John C. Maxwell
# 4267  Make Today Count: The Secret of Your Success I...  John C. Maxwell
# 4268                             वॉयर - एक कामुक लघुकथा    सेसिलि रोसडैल
# 4269                             वॉयर - एक कामुक लघुकथा    सेसिलि रोसडैल
#
#       Rating_x  Number of Reviews_x  Price_x         Author_y  Rating_y  \
# ...

# %%
df = pd.merge(df1, df2, on="Book Name", how = 'inner')
df
# Out:
#                                               Book Name         Author_x  \
# 0     Think Like a Monk: The Secret of How to Harnes...       Jay Shetty
# 1     Ikigai: The Japanese Secret to a Long and Happ...    Héctor García
# 2     The Subtle Art of Not Giving a F*ck: A Counter...      Mark Manson
# 3     Atomic Habits: An Easy and Proven Way to Build...      James Clear
# 4     Life's Amazing Secrets: How to Find Balance an...   Gaur Gopal Das
# ...                                                 ...              ...
# 4265                         The Prophet & The Wanderer    Khalil Gibran
# 4266  Make Today Count: The Secret of Your Success I...  John C. Maxwell
# 4267  Make Today Count: The Secret of Your Success I...  John C. Maxwell
# 4268                             वॉयर - एक कामुक लघुकथा    सेसिलि रोसडैल
# 4269                             वॉयर - एक कामुक लघुकथा    सेसिलि रोसडैल
#
#       Rating_x  Number of Reviews_x  Price_x         Author_y  Rating_y  \
# ...

# %%
df[df['Author_x'] != df['Author_y']]
# Out:
#                     Book Name               Author_x  Rating_x  \
# 54    Autobiography of a Yogi  Paramahansa Yogananda       4.6
# 291   Autobiography of a Yogi   Paramhansa Yogananda      -1.0
# 316                Siddhartha          Hermann Hesse       4.3
# 596     The Prodigal Daughter         Jeffrey Archer      -1.0
# 1238              The Prophet          Khalil Gibran       4.4
# 1239              The Prophet          Khalil Gibran       4.4
# 1240              The Prophet          Khalil Gibran       4.4
# 1325               Cinderella       Charles Perrault      -1.0
# 1494              The Prophet          Kahlil Gibran       4.5
# 1555              The Prophet          Kahlil Gibran       4.5
# 1803               Cinderella            Jacob Grimm      -1.0
# 2790              Meditations          Shakti Gawain       4.4
# 3487                The Idiot           Elif Batuman       3.7
# 3488        Playing for Keeps           Kendall Ryan       4.5
# ...

# %%
df[df['Number of Reviews_x'] > df['Number of Reviews_y']].shape
# Out:
# (14, 12)

# %%
df[df['Number of Reviews_x'] < df['Number of Reviews_y']].shape
# Out:
# (2494, 12)

# %%
df.shape
# Out:
# (4270, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4270 entries, 0 to 4269
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Book Name            4270 non-null   object
#  1   Author_x             4270 non-null   object
#  2   Rating_x             4270 non-null   float64
#  3   Number of Reviews_x  3853 non-null   float64
#  4   Price_x              4268 non-null   float64
#  5   Author_y             4270 non-null   object
#  6   Rating_y             4270 non-null   float64
#  7   Number of Reviews_y  3855 non-null   float64
#  8   Price_y              4270 non-null   int64
#  9   Description          4264 non-null   object
#  10  Listening Time       4270 non-null   object
#  11  Ranks and Genre      4270 non-null   object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 400.4+ KB

# %%
df1.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Book Name          6368 non-null   object
#  1   Author             6368 non-null   object
#  2   Rating             6368 non-null   float64
#  3   Number of Reviews  5737 non-null   float64
#  4   Price              6365 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 248.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4464 entries, 0 to 4463
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Book Name          4464 non-null   object
#  1   Author             4464 non-null   object
#  2   Rating             4464 non-null   float64
#  3   Number of Reviews  4043 non-null   float64
#  4   Price              4464 non-null   int64
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                               Book Name  \
# 54                              Autobiography of a Yogi
# 56    FREE: Professional Integrity (A Riyria Chronic...
# 124          Flow: Living at the Peak of Your Abilities
# 135   Kyon Se Shuruwat Karein [Start with Why]: Maha...
# 151          H.G. Wells: The Science Fiction Collection
# ...                                                 ...
# 4250                             वॉयर - एक कामुक लघुकथा
# 4251           द गेम विद मिस्टर एक्‍स - एक कामुक लघुकथा
# 4252           द गेम विद मिस्टर एक्‍स - एक कामुक लघुकथा
# 4268                             वॉयर - एक कामुक लघुकथा
# 4269                             वॉयर - एक कामुक लघुकथा
#
#                            Author_x  Rating_x  Number of Reviews_x  Price_x  \
# 54            Paramahansa Yogananda       4.6               2233.0   1126.0
# 56              Michael J. Sullivan      -1.0                  NaN      0.0
# ...

# %%
df=df1.merge(df2, on='Book Name', how='outer', indicator=True)
df
# Out:
#                                               Book Name  \
# 0     "Don't You Know Who I Am?": How to Stay Sane i...
# 1     "Don't You Know Who I Am?": How to Stay Sane i...
# 2                                             #Girlboss
# 3                                             #Girlboss
# 4     #TheRealCinderella: #BestFriendsForever Series...
# ...                                                 ...
# 7573              माय एबडक्शन फ़ैन्टसी - एक कामुक लघुकथा
# 7574                             वॉयर - एक कामुक लघुकथा
# 7575                             वॉयर - एक कामुक लघुकथा
# 7576                             वॉयर - एक कामुक लघुकथा
# 7577                             वॉयर - एक कामुक लघुकथा
#
#                      Author_x  Rating_x  Number of Reviews_x  Price_x  \
# 0     Ramani S. Durvasula PhD       4.8                170.0    836.0
# 1     Ramani S. Durvasula PhD       4.8                170.0    836.0
# 2              Sophia Amoruso       4.5               2260.0    615.0
# ...

# %%
df[df['_merge'] == 'left_only']
# Out:
#                                               Book Name  \
# 0     "Don't You Know Who I Am?": How to Stay Sane i...
# 1     "Don't You Know Who I Am?": How to Stay Sane i...
# 10                     10 Judgements That Changed India
# 14    10 Steps to Earning Awesome Grades (While Stud...
# 16                      100 Desi Stories to Inspire You
# ...                                                 ...
# 7561  Zone to Win: Organizing to Compete in an Age o...
# 7562            Zoology: Understanding the Animal World
# 7563                                    Zorba the Greek
# 7564           ऑब्सेस्ड विद ओवेन ग्रे - एक कामुक लघुकथा
# 7573              माय एबडक्शन फ़ैन्टसी - एक कामुक लघुकथा
#
#                      Author_x  Rating_x  Number of Reviews_x  Price_x  \
# 0     Ramani S. Durvasula PhD       4.8                170.0    836.0
# 1     Ramani S. Durvasula PhD       4.8                170.0    836.0
# 10                   Zia Mody       4.4                221.0    502.0
# ...

# %% [markdown]
# 2561 rows are available in df1 (Audible Catlog)

# %%
df[df['_merge'] == 'right_only']
# Out:
#                                               Book Name Author_x  Rating_x  \
# 21    1000+ Little Things Happy Successful People Do...      NaN       NaN
# 64    21-Day Challenges Box Set 1 - Self Love, Self ...      NaN       NaN
# 65                                             22.11.63      NaN       NaN
# 80                                     365 Jataka Tales      NaN       NaN
# 81                                     365 Jataka Tales      NaN       NaN
# ...                                                 ...      ...       ...
# 7533  Your Soul's Plan: Discovering the Real Meaning...      NaN       NaN
# 7535  You’re Not Listening: What You’re Missing and ...      NaN       NaN
# 7536  You’re Not Listening: What You’re Missing and ...      NaN       NaN
# 7558  Zindagi Wo Jo Aap Banaayen [Life Is What You M...      NaN       NaN
# 7560                                                Zog      NaN       NaN
#
# ...

# %% [markdown]
# 747 rows are in the right dataframe (in advanced features dataframe and not in simple audible catlog)

# %%
df[df.duplicated(subset=['Book Name'])]
# Out:
#                                               Book Name  \
# 1     "Don't You Know Who I Am?": How to Stay Sane i...
# 3                                             #Girlboss
# 6                    10 Bedtime Stories For Little Kids
# 8                     10 Essential Pieces of Literature
# 17                      100 Desi Stories to Inspire You
# ...                                                 ...
# 7570           द गेम विद मिस्टर एक्‍स - एक कामुक लघुकथा
# 7572             द निम्फ़ एंड द फ़ॉन्स - एक कामुक लघुकथा
# 7575                             वॉयर - एक कामुक लघुकथा
# 7576                             वॉयर - एक कामुक लघुकथा
# 7577                             वॉयर - एक कामुक लघुकथा
#
#                      Author_x  Rating_x  Number of Reviews_x  Price_x  \
# 1     Ramani S. Durvasula PhD       4.8                170.0    836.0
# 3              Sophia Amoruso       4.5               2260.0    615.0
# 6                        div.      -1.0                  NaN    376.0
# ...

# %%
df[df['_merge'] == 'right_only'].duplicated(subset=['Book Name']).count()
# Out:
# np.int64(747)

# %%
df[df['_merge'] == 'both'].duplicated(subset=['Book Name']).count()
# Out:
# np.int64(4270)

# %%
df[df.duplicated(subset=['Book Name'])]
# Out:
#                                               Book Name  \
# 1     "Don't You Know Who I Am?": How to Stay Sane i...
# 3                                             #Girlboss
# 6                    10 Bedtime Stories For Little Kids
# 8                     10 Essential Pieces of Literature
# 17                      100 Desi Stories to Inspire You
# ...                                                 ...
# 7570           द गेम विद मिस्टर एक्‍स - एक कामुक लघुकथा
# 7572             द निम्फ़ एंड द फ़ॉन्स - एक कामुक लघुकथा
# 7575                             वॉयर - एक कामुक लघुकथा
# 7576                             वॉयर - एक कामुक लघुकथा
# 7577                             वॉयर - एक कामुक लघुकथा
#
#                      Author_x  Rating_x  Number of Reviews_x  Price_x  \
# 1     Ramani S. Durvasula PhD       4.8                170.0    836.0
# 3              Sophia Amoruso       4.5               2260.0    615.0
# 6                        div.      -1.0                  NaN    376.0
# ...

# %%
df['Book Name'].nunique()
# Out:
# 6054

# %%
df1.shape
# Out:
# (6368, 5)

# %%
df1[df1['Book Name'].duplicated()].count()
# Out:
# Book Name            972
# Author               972
# Rating               972
# Number of Reviews    863
# Price                971
# dtype: int64

# %%
df2[df2['Book Name'].duplicated()].count()
# Out:
# Book Name            457
# Author               457
# Rating               457
# Number of Reviews    413
# Price                457
# Description          457
# Listening Time       457
# Ranks and Genre      457
# dtype: int64

# %%
# book in df1 not available in df2 = 
df1[~df1['Book Name'].isin(df2['Book Name'])]
# Out:
#                                               Book Name  \
# 61        Scion of Ikshvaku: Ram Chandra Series, Book 1
# 62                             Sita: Warrior of Mithila
# 65      Harry Potter and the Chamber of Secrets, Book 2
# 68    Make Time: How to focus on what matters every day
# 69    The Other America - A Speech from The Radical ...
# ...                                                 ...
# 6357  Maximum Influence: 2nd Edition: The 12 Univers...
# 6360                              Reconstructing Amelia
# 6362               False Gods: The Horus Heresy, Book 2
# 6363                                 The Hot Flash Club
# 6366  25 Hours a Day: Going One More to Get What You...
#
#                           Author  Rating  Number of Reviews   Price
# 61                         Amish     4.2             6475.0   836.0
# 62                         Amish     4.4             3804.0   836.0
# 65                  J.K. Rowling     4.7            10362.0   999.0
# ...

# %%
df2[~df2['Book Name'].isin(df1['Book Name'])]
# Out:
#                                               Book Name  \
# 426   Mastering the Trade, Third Edition: Proven Tec...
# 573   Dan Brown: Audible Sessions: FREE Exclusive In...
# 644                                              Devlok
# 736                                        Naughty Boss
# 796                                            Beartown
# ...                                                 ...
# 4457  Captain Underpants and the Perilous Plot of Pr...
# 4458                                  The Little Prince
# 4459  Factfulness: Wie wir lernen, die Welt so zu se...
# 4460       Late-Talking Children: A Symptom or a Stage?
# 4461  The Marketing of Evil: How Radicals, Elitists ...
#
#                         Author  Rating  Number of Reviews  Price  \
# 426                John Carter     4.6              122.0    836
# 573               Holly Newson     5.0                2.0      0
# 644          Devdutt Pattanaik     4.3              856.0    703
# ...
